# %%
import polars as pl
import os
from tqdm import tqdm 
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
from pathlib import Path

# %% [markdown]
# # Cleaning stops_0.csv

# %%
# Load stops.csv
stops = pd.read_csv(r"C:\Users\moham\Downloads\Data_Cleaning\stops_0.csv")

# Load route_to_stop_sequence to filter stop_ids
route_to_stop = pd.read_csv(r"C:\Users\moham\Downloads\Data_Cleaning\route_to_stop_sequence_v2.csv")

# Extract all stop_ids used in any route
used_stop_ids = set()
for seq in route_to_stop['stop_id_list']:
    # Each stop_id_list might be a string representation of list -> convert properly
    ids = eval(seq) if isinstance(seq, str) else seq
    used_stop_ids.update(map(int, ids))

# Clean stops.csv
stops_clean = (
    stops
    .drop(columns=["stop_name"], errors="ignore")     # remove stop_name
    .query("stop_id in @used_stop_ids")               # keep only used stops
)

# Ensure correct dtypes
stops_clean = stops_clean.astype({
    "stop_id": "Int64",
    "stop_lat": "float64",
    "stop_lon": "float64"
})

print(stops_clean.dtypes)
stops_clean.to_csv("stops_clean.csv", index=False)

# %% [markdown]
# # Cleaning route_to_stop_sequence.csv

# %%
# Load route_to_stop_sequence
route_to_stop = pd.read_csv(r"C:\Users\moham\Downloads\Data_Cleaning\route_to_stop_sequence_v2.csv")

# Convert stop_id_list column (string → list[int])
def parse_stop_list(x):
    if isinstance(x, str):
        return [int(i) for i in x.strip("[]").replace("'", "").split(",") if i.strip()]
    return []

route_to_stop["stop_id_list"] = route_to_stop["stop_id_list"].apply(parse_stop_list)

# Ensure correct dtype
route_to_stop = route_to_stop.astype({"route_id": "Int64"})

print(route_to_stop.head())
route_to_stop.to_csv("route_to_stop_clean.csv")  # save with Python list preserved

# %% [markdown]
# # PROCESSING PARQUET FILES WHICH WERE GIVEN TO US

# %%
# parent_dir = raw daily folders, each containing 5–6 parquet files
parent_dir = r"C:\Users\moham\OneDrive\Desktop\Bengaluru Vega\Code\task_1\Demo_date_wise_data" # INPUT data path

# NEW BASE OUTPUT LOCATION (outside of OneDrive)
new_base_dir = r"C:\Temp_Bengaluru_Output"  #Create your own temp folder here
base_output = os.path.join(new_base_dir, "cleaned_dataset_partitioned")

# OUTPUT DIRECTORY: Will hold the partitioned route folders (e.g., route_id_101)
output_dir = os.path.join(base_output, "routes_partitioned") # Changed name for clarity
checkpoint_dir = os.path.join(base_output, "checkpoints")

# %%
# make sure base folders exist
os.makedirs(output_dir, exist_ok=True) 
os.makedirs(checkpoint_dir, exist_ok=True) 


# ----------------------------
# HELPER: decode byte-like columns (Kept from first block)
# ----------------------------
def decode_bytes(df: pl.DataFrame, cols: list[str]) -> pl.DataFrame:
    """Decode b'...' style bytes safely into strings."""
    for col in cols:
        if col in df.columns:
            df = df.with_columns(
                pl.col(col).map_elements(
                    lambda x: (
                        x.decode("utf-8").strip('"')
                        if isinstance(x, (bytes, bytearray))
                        else str(x).strip('"') if x is not None else None
                    ),
                    return_dtype=pl.Utf8
                ).alias(col)
            )
    return df

# ----------------------------
# COLUMNS TO RETAIN 
# ----------------------------
cols = [
    "vehicle_timestamp", "trip_id", "schedule_relationship",
    "route_id", "latitude", "longitude", "bearing"
]

# ----------------------------
# PIPELINE
# ----------------------------
for day_folder in os.listdir(parent_dir):
    full_path = os.path.join(parent_dir, day_folder)
    if not os.path.isdir(full_path):
        continue

    checkpoint_file = os.path.join(checkpoint_dir, f"{day_folder}.done")

    if os.path.exists(checkpoint_file):
        print(f"⏭ Skipping {day_folder} (already processed)")
        continue

    print(f"\n📦 Processing {day_folder} ...")
    
    # List to hold lazy frames for this day
    lazy_frames = []

    # loop over parquet files inside this day folder
    parquet_files = [
        os.path.join(full_path, f)
        for f in os.listdir(full_path)
        if f.endswith(".parquet")
    ]

    for pq_file in tqdm(parquet_files, desc=f"  → {day_folder}"):
        # lazy scan and select target columns
        lf = pl.scan_parquet(pq_file).select(
             [c for c in cols if c in pl.scan_parquet(pq_file).collect_schema().names()]
        )
        lazy_frames.append(lf)
    
    if not lazy_frames:
        print(f"⚠ No parquet files found in {day_folder}, skipping.")
        continue

    # Concatenate all lazy frames for the day and collect into memory
    lf_all = pl.concat(lazy_frames)
    df = lf_all.collect()
    
    # ----------------------------
    # CLEANING
    # ----------------------------

    # REMOVE DUPLICATES (done once on the collected daily data)
    
    df = df.unique(subset=['trip_id', 'vehicle_timestamp'], keep='first')
    
    df = decode_bytes(df, cols)

    # Convert vehicle_timestamp → datetime (USING MILLISECONDS CONVERSION)
    if "vehicle_timestamp" in df.columns:
        df = df.with_columns(
            pl.col("vehicle_timestamp")
            .cast(pl.Int64, strict=False)
            # Convert seconds (input) to milliseconds by multiplying by 1000
            .mul(1000) 
            .cast(pl.Datetime("ms"), strict=False) 
            .alias("vehicle_timestamp")
        )

    # Convert numerics
    # Note: Added "current_status" and "start_date" from the second block's numeric list
    for col in ["current_status", "trip_id", "route_id", "start_date"]:
        if col in df.columns:
            df = df.with_columns(pl.col(col).cast(pl.Int64, strict=False))

    # Normalize schedule_relationship & drop canceled
    if "schedule_relationship" in df.columns:
        df = df.with_columns(
            pl.col("schedule_relationship")
            .cast(pl.Utf8)
            .str.to_uppercase()
            .alias("schedule_relationship")
        )
        # Drop CANCELED trips (consistent with the cleaning goal)
        df = df.filter(pl.col("schedule_relationship") != "CANCELED")

    # Convert floats
    for col in ["latitude", "longitude", "bearing"]:
        if col in df.columns:
            df = df.with_columns(pl.col(col).cast(pl.Float64, strict=False))

    # ----------------------------
    # BROADCAST route_id WITHIN trip_id (Adopted from second block)
    # ----------------------------
    if "trip_id" in df.columns and "route_id" in df.columns:
        print("   → Applying route_id broadcast within trip_id groups...")
        df = (
            df.sort(["trip_id", "vehicle_timestamp"])
             .with_columns(
                 pl.col("route_id")
                 .fill_null(strategy="forward")
                 .fill_null(strategy="backward")
                 .over("trip_id")
                 .alias("route_id")
             )
        )
        
    # ----------------------------
    # SPLIT BY route_id AND SAVE (Partitioning like the second block)
    # ----------------------------
    # Drop rows where route_id is still null after the broadcast (e.g., UNSCHEDULED)
    unique_routes = df["route_id"].unique().drop_nulls().to_list() 
    print(f"✅ {len(unique_routes)} unique routes found in {day_folder} for saving.")

    # Sort the dataframe one last time for efficient filtering/saving
    df = df.sort(["route_id", "trip_id", "vehicle_timestamp"])
    
    for rid in tqdm(unique_routes, desc=f"✍ Saving routes for date={day_folder}"):
        df_route = df.filter(pl.col("route_id") == rid).select(cols) 

        # Create folder for each route
        route_folder = os.path.join(output_dir, f"route_id_{rid}")
        os.makedirs(route_folder, exist_ok=True)

        # File format: route_<rid>day<day_folder>.parquet
        out_path = os.path.join(route_folder, f"route_{rid}day{day_folder}.parquet")
        
        # Save the partitioned file
        df_route.write_parquet(out_path)

    # create checkpoint marker
    with open(checkpoint_file, "w") as f:
        f.write("done")

    print(f"✔ Finished {day_folder} and checkpointed. Files saved in {output_dir}")


print("\n🎉 All days processed successfully and saved partitioned by route_id!")
# Out:
# 📦 Processing date=2025-08-10 ...
#   → date=2025-08-10: 100%|██████████| 2/2 [00:00<00:00, 96.81it/s]
#    → Applying route_id broadcast within trip_id groups...
# ✅ 2883 unique routes found in date=2025-08-10 for saving.
# ✍ Saving routes for date=date=2025-08-10: 100%|██████████| 2883/2883 [00:05<00:00, 493.96it/s]
# ✔ Finished date=2025-08-10 and checkpointed. Files saved in C:\Temp_Bengaluru_Output\cleaned_dataset_partitioned\routes_partitioned
#
# 📦 Processing date=2025-08-17 ...
#   → date=2025-08-17: 100%|██████████| 2/2 [00:00<00:00, 127.84it/s]
#    → Applying route_id broadcast within trip_id groups...
# ✅ 3955 unique routes found in date=2025-08-17 for saving.
# ✍ Saving routes for date=date=2025-08-17: 100%|██████████| 3955/3955 [00:11<00:00, 355.84it/s]
# ✔ Finished date=2025-08-17 and checkpointed. Files saved in C:\Temp_Bengaluru_Output\cleaned_dataset_partitioned\routes_partitioned
#
# 🎉 All days processed successfully and saved partitioned by route_id!

# %% [markdown]
# # Comparison Between df_old and processed df_new_route_id_1657

# %%
df_old = pd.read_parquet(r"C:\Users\moham\OneDrive\Desktop\Bengaluru Vega\Code\task_1\Demo_date_wise_data\date=2025-08-10\part-00000-b87f0d47-fbdd-42bf-8877-034accb68352.c000.snappy_flat.parquet")

# %%
df_old.sample(4)
# Out:
#            id                 system_time current_status  stop_id  \
# 4093301  8229  2025-08-10T07:25:35.892169              1  "22406"
# 6838002  9622  2025-08-10T05:53:35.931186              1  "38058"
# 3469383  8303  2025-08-10T07:18:05.827047              1  "36368"
# 2745982  6872  2025-08-10T06:35:15.881866              1  "38058"
#
#         vehicle_timestamp     trip_id  start_time  start_date  \
# 4093301      "1754810708"  "67527469"  "06:15:00"  "20250810"
# 6838002      "1754805176"  "67428350"  "05:45:00"  "20250810"
# 3469383      "1754810255"  "67454621"  "06:35:00"  "20250810"
# 2745982      "1754807687"  "67454271"  "05:25:00"  "20250810"
#
#         schedule_relationship route_id   latitude  longitude  bearing  \
# 4093301           "SCHEDULED"   "2606"  12.948546  77.497093    196.0
# 6838002           "SCHEDULED"  "14189"  13.008821  77.643013    227.0
# 3469383           "SCHEDULED"   "3139"  13.000056  77.676849    269.0
# 2745982           "SCHEDULED"   "1856"  12.956732  77.697113     37.0
#
#         vehicle_id         label
# 4093301    "20389"   "KA57F4286"
# 6838002    "20804"   "KA57F2203"
# 3469383    "23454"   "KA41D2747"
# 2745982    "28343"  "KA01AR0778"

# %%
df_new_route_1657= pd.read_parquet(r"C:\Temp_Bengaluru_Output\cleaned_dataset_partitioned\routes_partitioned\route_id_1657\route_1657daydate=2025-08-10.parquet")

# %%
df.head()
# Out:
#     vehicle_timestamp   trip_id schedule_relationship  route_id   latitude  \
# 0 2025-08-10 05:25:48  67410793             SCHEDULED      1657  12.980172
# 1 2025-08-10 05:26:48  67410793             SCHEDULED      1657  12.982033
# 2 2025-08-10 05:27:18  67410793             SCHEDULED      1657  12.984824
# 3 2025-08-10 05:27:48  67410793             SCHEDULED      1657  12.987010
# 4 2025-08-10 05:28:18  67410793             SCHEDULED      1657  12.987882
#
#    longitude  bearing
# 0  77.571899     73.0
# 1  77.574593    358.0
# 2  77.574806    354.0
# 3  77.574463    350.0
# 4  77.574242    335.0

# %% [markdown]
# # Combining the different route_id's

# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
from pathlib import Path


DATA_DIR = Path(r"C:\Temp_Bengaluru_Output\cleaned_dataset_partitioned\routes_partitioned")
STOPS_FILE = Path(r"C:\Users\moham\Downloads\Data_Cleaning\cleaned_data\stops_clean.csv")
ROUTE_STOPS_FILE = Path(r"C:\Users\moham\Downloads\Data_Cleaning\cleaned_data\route_to_stop_clean.csv")

# ---------------------------
# Data Loading and Initial Cleaning
# ---------------------------
def load_all_raw_data(base_dir, known_routes):
    all_data = []
    for route_dir in base_dir.iterdir():
        route_id_str = route_dir.name.replace('route_id_', '')
        if route_dir.is_dir() and int(route_id_str) in known_routes:
            print(f"Loading data for {route_dir.name}...")
            for file_path in route_dir.glob('*.parquet'):
                try:
                    df = pd.read_parquet(file_path)
                    df = df.drop_duplicates()
                    all_data.append(df)
                except Exception as e:
                    print(f"Error loading {file_path}: {e}")
    
    if all_data:
        combined_df = pd.concat(all_data, ignore_index=True)
        
        return combined_df
    else:
        return pd.DataFrame()

route_stops = pd.read_csv(ROUTE_STOPS_FILE)
known_routes = set(route_stops['route_id'].unique())
route_stops["stop_id_list"] = route_stops["stop_id_list"].apply(lambda x: eval(x))

combined_df = load_all_raw_data(DATA_DIR, known_routes)
# Out:
# Loading data for route_id_10004...
# Loading data for route_id_10016...
# Loading data for route_id_10019...
# Loading data for route_id_10020...
# Loading data for route_id_10034...
# Loading data for route_id_10044...
# Loading data for route_id_10045...
# Loading data for route_id_10069...
# Loading data for route_id_10070...
# Loading data for route_id_10071...
# Loading data for route_id_10072...
# Loading data for route_id_10094...
# Loading data for route_id_10108...
# Loading data for route_id_10109...
# Loading data for route_id_10122...
# Loading data for route_id_10144...
# Loading data for route_id_10164...
# Loading data for route_id_10165...
# Loading data for route_id_10201...
# Loading data for route_id_10210...
# Loading data for route_id_10211...
# Loading data for route_id_10219...
# Loading data for route_id_10221...
# Loading data for route_id_10239...
# Loading data for route_id_10260...
# Loading data for route_id_10262...
# Loading data for route_id_10264...
# Loading data for route_id_10271...
# Loading data for route_id_10272...
# Loading data for route_id_10273...
# Loading data for route_id_10274...
# Loading data for route_id_10280...
# Loading data for route_id_10286...
# Loading data for route_id_10295...
# Loading data for route_id_10296...
# Loading data for route_id_10315...
# Loading data for route_id_10320...
# Loading data for route_id_10334...
# Loading data for route_id_10384...
# Loading data for route_id_10396...
# Loading data for route_id_10397...
# Loading data for route_id_10399...
# Loading data for route_id_10406...
# Loading data for route_id_10407...
# Loading data for route_id_10412...
# Loading data for route_id_10443...
# Loading data for route_id_10472...
# Loading data for route_id_10514...
# Loading data for route_id_10515...
# Loading data for route_id_10525...
# Loading data for route_id_10526...
# Loading data for route_id_10547...
# Loading data for route_id_10548...
# Loading data for route_id_10549...
# Loading data for route_id_10550...
# Loading data for route_id_10568...
# Loading data for route_id_10570...
# Loading data for route_id_10575...
# Loading data for route_id_10576...
# Loading data for route_id_10585...
# Loading data for route_id_10589...
# Loading data for route_id_10593...
# Loading data for route_id_10594...
# Loading data for route_id_10626...
# Loading data for route_id_10627...
# Loading data for route_id_10628...
# Loading data for route_id_10629...
# Loading data for route_id_10642...
# Loading data for route_id_10681...
# Loading data for route_id_10682...
# Loading data for route_id_10695...
# Loading data for route_id_10740...
# Loading data for route_id_10748...
# Loading data for route_id_10794...
# Loading data for route_id_10796...
# Loading data for route_id_10837...
# Loading data for route_id_10840...
# Loading data for route_id_10841...
# Loading data for route_id_10842...
# Loading data for route_id_10846...
# Loading data for route_id_10870...
# Loading data for route_id_10872...
# Loading data for route_id_10873...
# Loading data for route_id_10875...
# Loading data for route_id_10881...
# Loading data for route_id_10882...
# Loading data for route_id_10886...
# Loading data for route_id_10887...
# Loading data for route_id_10890...
# Loading data for route_id_10895...
# Loading data for route_id_10898...
# Loading data for route_id_10899...
# Loading data for route_id_10916...
# Loading data for route_id_10922...
# Loading data for route_id_10929...
# Loading data for route_id_10930...
# Loading data for route_id_10931...
# Loading data for route_id_10932...
# Loading data for route_id_10934...
# Loading data for route_id_10951...
# Loading data for route_id_10952...
# Loading data for route_id_10957...
# Loading data for route_id_10958...
# Loading data for route_id_10959...
# Loading data for route_id_10962...
# Loading data for route_id_10966...
# Loading data for route_id_10974...
# Loading data for route_id_10996...
# Loading data for route_id_11004...
# Loading data for route_id_11022...
# Loading data for route_id_11039...
# Loading data for route_id_11042...
# Loading data for route_id_11043...
# Loading data for route_id_11060...
# Loading data for route_id_11068...
# Loading data for route_id_11069...
# Loading data for route_id_11103...
# Loading data for route_id_11104...
# Loading data for route_id_11128...
# Loading data for route_id_11129...
# Loading data for route_id_11138...
# Loading data for route_id_11148...
# Loading data for route_id_11149...
# Loading data for route_id_11160...
# Loading data for route_id_11161...
# Loading data for route_id_11174...
# Loading data for route_id_11177...
# Loading data for route_id_11178...
# Loading data for route_id_11201...
# Loading data for route_id_11210...
# Loading data for route_id_11211...
# Loading data for route_id_11212...
# Loading data for route_id_11213...
# Loading data for route_id_11221...
# Loading data for route_id_11223...
# Loading data for route_id_11228...
# Loading data for route_id_11231...
# Loading data for route_id_11237...
# Loading data for route_id_11238...
# Loading data for route_id_11239...
# Loading data for route_id_11240...
# Loading data for route_id_11241...
# Loading data for route_id_11251...
# Loading data for route_id_11256...
# Loading data for route_id_11261...
# Loading data for route_id_11262...
# Loading data for route_id_11293...
# Loading data for route_id_11296...
# Loading data for route_id_11297...
# Loading data for route_id_11301...
# Loading data for route_id_11307...
# Loading data for route_id_11313...
# Loading data for route_id_11314...
# Loading data for route_id_11315...
# Loading data for route_id_11316...
# Loading data for route_id_11358...
# Loading data for route_id_11359...
# Loading data for route_id_11364...
# Loading data for route_id_11365...
# Loading data for route_id_11377...
# Loading data for route_id_11378...
# Loading data for route_id_11384...
# Loading data for route_id_11394...
# Loading data for route_id_11395...
# Loading data for route_id_11403...
# Loading data for route_id_11405...
# Loading data for route_id_11420...
# Loading data for route_id_11421...
# Loading data for route_id_11423...
# Loading data for route_id_11424...
# Loading data for route_id_11430...
# Loading data for route_id_11435...
# Loading data for route_id_11437...
# Loading data for route_id_11440...
# Loading data for route_id_11477...
# Loading data for route_id_11478...
# Loading data for route_id_11479...
# Loading data for route_id_11515...
# Loading data for route_id_11516...
# Loading data for route_id_11517...
# Loading data for route_id_11519...
# Loading data for route_id_11520...
# Loading data for route_id_11521...
# Loading data for route_id_11529...
# Loading data for route_id_11530...
# Loading data for route_id_11547...
# Loading data for route_id_11555...
# Loading data for route_id_11556...
# Loading data for route_id_11581...
# Loading data for route_id_11590...
# Loading data for route_id_11628...
# Loading data for route_id_11642...
# Loading data for route_id_11656...
# Loading data for route_id_11692...
# Loading data for route_id_11712...
# Loading data for route_id_11714...
# Loading data for route_id_11715...
# Loading data for route_id_11732...
# Loading data for route_id_11772...
# Loading data for route_id_11775...
# Loading data for route_id_11776...
# Loading data for route_id_11782...
# Loading data for route_id_11783...
# Loading data for route_id_11845...
# Loading data for route_id_11847...
# Loading data for route_id_11848...
# Loading data for route_id_11869...
# Loading data for route_id_11870...
# Loading data for route_id_11875...
# Loading data for route_id_11876...
# Loading data for route_id_11877...
# Loading data for route_id_11878...
# Loading data for route_id_11881...
# Loading data for route_id_11882...
# Loading data for route_id_11895...
# Loading data for route_id_11896...
# Loading data for route_id_11899...
# Loading data for route_id_11900...
# Loading data for route_id_11920...
# Loading data for route_id_11929...
# Loading data for route_id_11930...
# Loading data for route_id_11953...
# Loading data for route_id_11961...
# Loading data for route_id_11969...
# Loading data for route_id_11970...
# Loading data for route_id_11971...
# Loading data for route_id_11972...
# Loading data for route_id_11976...
# Loading data for route_id_11977...
# Loading data for route_id_11986...
# Loading data for route_id_11994...
# Loading data for route_id_11995...
# Loading data for route_id_11996...
# Loading data for route_id_11997...
# Loading data for route_id_12006...
# Loading data for route_id_12084...
# Loading data for route_id_12085...
# Loading data for route_id_12087...
# Loading data for route_id_12092...
# Loading data for route_id_12126...
# Loading data for route_id_12127...
# Loading data for route_id_12136...
# Loading data for route_id_12137...
# Loading data for route_id_12138...
# Loading data for route_id_12139...
# Loading data for route_id_12148...
# Loading data for route_id_12149...
# Loading data for route_id_12151...
# Loading data for route_id_12162...
# Loading data for route_id_12163...
# Loading data for route_id_12168...
# Loading data for route_id_12194...
# Loading data for route_id_12234...
# Loading data for route_id_12238...
# Loading data for route_id_12247...
# Loading data for route_id_12248...
# Loading data for route_id_12286...
# Loading data for route_id_12287...
# Loading data for route_id_12289...
# Loading data for route_id_12290...
# Loading data for route_id_12293...
# Loading data for route_id_12294...
# Loading data for route_id_12305...
# Loading data for route_id_12306...
# Loading data for route_id_12307...
# Loading data for route_id_12308...
# Loading data for route_id_12313...
# Loading data for route_id_12316...
# Loading data for route_id_12317...
# Loading data for route_id_12324...
# Loading data for route_id_12325...
# Loading data for route_id_12328...
# Loading data for route_id_12329...
# Loading data for route_id_12331...
# Loading data for route_id_12332...
# Loading data for route_id_12337...
# Loading data for route_id_12338...
# Loading data for route_id_12339...
# Loading data for route_id_12340...
# Loading data for route_id_12341...
# Loading data for route_id_12342...
# Loading data for route_id_12343...
# Loading data for route_id_12344...
# Loading data for route_id_12347...
# Loading data for route_id_12365...
# Loading data for route_id_12378...
# Loading data for route_id_12379...
# Loading data for route_id_12380...
# Loading data for route_id_12391...
# Loading data for route_id_12393...
# Loading data for route_id_12396...
# Loading data for route_id_12398...
# Loading data for route_id_12399...
# Loading data for route_id_12403...
# Loading data for route_id_12412...
# Loading data for route_id_12413...
# Loading data for route_id_12416...
# Loading data for route_id_12424...
# Loading data for route_id_12425...
# Loading data for route_id_12440...
# Loading data for route_id_12441...
# Loading data for route_id_12442...
# Loading data for route_id_12453...
# Loading data for route_id_12454...
# Loading data for route_id_12473...
# Loading data for route_id_12474...
# Loading data for route_id_12476...
# Loading data for route_id_12481...
# Loading data for route_id_12482...
# Loading data for route_id_12493...
# Loading data for route_id_12507...
# Loading data for route_id_12508...
# Loading data for route_id_12509...
# Loading data for route_id_12510...
# Loading data for route_id_12511...
# Loading data for route_id_12512...
# Loading data for route_id_12519...
# Loading data for route_id_12520...
# Loading data for route_id_12527...
# Loading data for route_id_12528...
# Loading data for route_id_12529...
# Loading data for route_id_12530...
# Loading data for route_id_12534...
# Loading data for route_id_12539...
# Loading data for route_id_12540...
# Loading data for route_id_12544...
# Loading data for route_id_12555...
# Loading data for route_id_12556...
# Loading data for route_id_12578...
# Loading data for route_id_12583...
# Loading data for route_id_12584...
# Loading data for route_id_12602...
# Loading data for route_id_12613...
# Loading data for route_id_12614...
# Loading data for route_id_12615...
# Loading data for route_id_12616...
# Loading data for route_id_12617...
# Loading data for route_id_12641...
# Loading data for route_id_12643...
# Loading data for route_id_12644...
# Loading data for route_id_12647...
# Loading data for route_id_12648...
# Loading data for route_id_12650...
# Loading data for route_id_12653...
# Loading data for route_id_12654...
# Loading data for route_id_12661...
# Loading data for route_id_12662...
# Loading data for route_id_12702...
# Loading data for route_id_12739...
# Loading data for route_id_12798...
# Loading data for route_id_12800...
# Loading data for route_id_12803...
# Loading data for route_id_12806...
# Loading data for route_id_12808...
# Loading data for route_id_12809...
# Loading data for route_id_12810...
# Loading data for route_id_12811...
# Loading data for route_id_12812...
# Loading data for route_id_12816...
# Loading data for route_id_12817...
# Loading data for route_id_12819...
# Loading data for route_id_12820...
# Loading data for route_id_12822...
# Loading data for route_id_12823...
# Loading data for route_id_12825...
# Loading data for route_id_12826...
# Loading data for route_id_12828...
# Loading data for route_id_12839...
# Loading data for route_id_12867...
# Loading data for route_id_12868...
# Loading data for route_id_12899...
# Loading data for route_id_12904...
# Loading data for route_id_12962...
# Loading data for route_id_12968...
# Loading data for route_id_12969...
# Loading data for route_id_12970...
# Loading data for route_id_12971...
# Loading data for route_id_12972...
# Loading data for route_id_12973...
# Loading data for route_id_12975...
# Loading data for route_id_12976...
# Loading data for route_id_12978...
# Loading data for route_id_12979...
# Loading data for route_id_12985...
# Loading data for route_id_12996...
# Loading data for route_id_13000...
# Loading data for route_id_13001...
# Loading data for route_id_13003...
# Loading data for route_id_13004...
# Loading data for route_id_13017...
# Loading data for route_id_13020...
# Loading data for route_id_13023...
# Loading data for route_id_13024...
# Loading data for route_id_13025...
# Loading data for route_id_13032...
# Loading data for route_id_13033...
# Loading data for route_id_13048...
# Loading data for route_id_13061...
# Loading data for route_id_13062...
# Loading data for route_id_13078...
# Loading data for route_id_13086...
# Loading data for route_id_13087...
# Loading data for route_id_13089...
# Loading data for route_id_13090...
# Loading data for route_id_13095...
# Loading data for route_id_13104...
# Loading data for route_id_13107...
# Loading data for route_id_13109...
# Loading data for route_id_13110...
# Loading data for route_id_13117...
# Loading data for route_id_13118...
# Loading data for route_id_13119...
# Loading data for route_id_13137...
# Loading data for route_id_13142...
# Loading data for route_id_13143...
# Loading data for route_id_13151...
# Loading data for route_id_13152...
# Loading data for route_id_13162...
# Loading data for route_id_13167...
# Loading data for route_id_13177...
# Loading data for route_id_13180...
# Loading data for route_id_13181...
# Loading data for route_id_13184...
# Loading data for route_id_13185...
# Loading data for route_id_13188...
# Loading data for route_id_13192...
# Loading data for route_id_13195...
# Loading data for route_id_13196...
# Loading data for route_id_13197...
# Loading data for route_id_13199...
# Loading data for route_id_13200...
# Loading data for route_id_13217...
# Loading data for route_id_13218...
# Loading data for route_id_13220...
# Loading data for route_id_13232...
# Loading data for route_id_13233...
# Loading data for route_id_13234...
# Loading data for route_id_13238...
# Loading data for route_id_13239...
# Loading data for route_id_13243...
# Loading data for route_id_13244...
# Loading data for route_id_13245...
# Loading data for route_id_13246...
# Loading data for route_id_13249...
# Loading data for route_id_13253...
# Loading data for route_id_13254...
# Loading data for route_id_13255...
# Loading data for route_id_13257...
# Loading data for route_id_13263...
# Loading data for route_id_13266...
# Loading data for route_id_13277...
# Loading data for route_id_13279...
# Loading data for route_id_13299...
# Loading data for route_id_13300...
# Loading data for route_id_13307...
# Loading data for route_id_13308...
# Loading data for route_id_13309...
# Loading data for route_id_13310...
# Loading data for route_id_13322...
# Loading data for route_id_13323...
# Loading data for route_id_13324...
# Loading data for route_id_13325...
# Loading data for route_id_13326...
# Loading data for route_id_13327...
# Loading data for route_id_13348...
# Loading data for route_id_13349...
# Loading data for route_id_13352...
# Loading data for route_id_13353...
# Loading data for route_id_13397...
# Loading data for route_id_13401...
# Loading data for route_id_13402...
# Loading data for route_id_13403...
# Loading data for route_id_13410...
# Loading data for route_id_13413...
# Loading data for route_id_13414...
# Loading data for route_id_13415...
# Loading data for route_id_13416...
# Loading data for route_id_13417...
# Loading data for route_id_13424...
# Loading data for route_id_13425...
# Loading data for route_id_13428...
# Loading data for route_id_13429...
# Loading data for route_id_13430...
# Loading data for route_id_13431...
# Loading data for route_id_13432...
# Loading data for route_id_13434...
# Loading data for route_id_13436...
# Loading data for route_id_13443...
# Loading data for route_id_13446...
# Loading data for route_id_13447...
# Loading data for route_id_13452...
# Loading data for route_id_13453...
# Loading data for route_id_13455...
# Loading data for route_id_13457...
# Loading data for route_id_13458...
# Loading data for route_id_13467...
# Loading data for route_id_13468...
# Loading data for route_id_13474...
# Loading data for route_id_13477...
# Loading data for route_id_13484...
# Loading data for route_id_13485...
# Loading data for route_id_13492...
# Loading data for route_id_13493...
# Loading data for route_id_13496...
# Loading data for route_id_13497...
# Loading data for route_id_13499...
# Loading data for route_id_13511...
# Loading data for route_id_13516...
# Loading data for route_id_13524...
# Loading data for route_id_13527...
# Loading data for route_id_13534...
# Loading data for route_id_13548...
# Loading data for route_id_13551...
# Loading data for route_id_13552...
# Loading data for route_id_13553...
# Loading data for route_id_13567...
# Loading data for route_id_13578...
# Loading data for route_id_13582...
# Loading data for route_id_13632...
# Loading data for route_id_13700...
# Loading data for route_id_13723...
# Loading data for route_id_13727...
# Loading data for route_id_13731...
# Loading data for route_id_13732...
# Loading data for route_id_13733...
# Loading data for route_id_13734...
# Loading data for route_id_13735...
# Loading data for route_id_13745...
# Loading data for route_id_13746...
# Loading data for route_id_13747...
# Loading data for route_id_13759...
# Loading data for route_id_13784...
# Loading data for route_id_13785...
# Loading data for route_id_13787...
# Loading data for route_id_13788...
# Loading data for route_id_13789...
# Loading data for route_id_13795...
# Loading data for route_id_13806...
# Loading data for route_id_13807...
# Loading data for route_id_13838...
# Loading data for route_id_13839...
# Loading data for route_id_13840...
# Loading data for route_id_13848...
# Loading data for route_id_13858...
# Loading data for route_id_13859...
# Loading data for route_id_13867...
# Loading data for route_id_13877...
# Loading data for route_id_13878...
# Loading data for route_id_13879...
# Loading data for route_id_13894...
# Loading data for route_id_13896...
# Loading data for route_id_13898...
# Loading data for route_id_13905...
# Loading data for route_id_13906...
# Loading data for route_id_13917...
# Loading data for route_id_13921...
# Loading data for route_id_13922...
# Loading data for route_id_13923...
# Loading data for route_id_13924...
# Loading data for route_id_13934...
# Loading data for route_id_13938...
# Loading data for route_id_13939...
# Loading data for route_id_13953...
# Loading data for route_id_13959...
# Loading data for route_id_13984...
# Loading data for route_id_13987...
# Loading data for route_id_13988...
# Loading data for route_id_13990...
# Loading data for route_id_13991...
# Loading data for route_id_14009...
# Loading data for route_id_14017...
# Loading data for route_id_14018...
# Loading data for route_id_14025...
# Loading data for route_id_14026...
# Loading data for route_id_14027...
# Loading data for route_id_14028...
# Loading data for route_id_14031...
# Loading data for route_id_14062...
# Loading data for route_id_14097...
# Loading data for route_id_14099...
# Loading data for route_id_14103...
# Loading data for route_id_14128...
# Loading data for route_id_14149...
# Loading data for route_id_14150...
# Loading data for route_id_14155...
# Loading data for route_id_14160...
# Loading data for route_id_14162...
# Loading data for route_id_14181...
# Loading data for route_id_14182...
# Loading data for route_id_14185...
# Loading data for route_id_14186...
# Loading data for route_id_14189...
# Loading data for route_id_14190...
# Loading data for route_id_14199...
# Loading data for route_id_14205...
# Loading data for route_id_14206...
# Loading data for route_id_14207...
# Loading data for route_id_14209...
# Loading data for route_id_14211...
# Loading data for route_id_14225...
# Loading data for route_id_14226...
# Loading data for route_id_14231...
# Loading data for route_id_14242...
# Loading data for route_id_14243...
# Loading data for route_id_14250...
# Loading data for route_id_14255...
# Loading data for route_id_14257...
# Loading data for route_id_14258...
# Loading data for route_id_14263...
# Loading data for route_id_14265...
# Loading data for route_id_14266...
# Loading data for route_id_14268...
# Loading data for route_id_14270...
# Loading data for route_id_14275...
# Loading data for route_id_14285...
# Loading data for route_id_14299...
# Loading data for route_id_14302...
# Loading data for route_id_14304...
# Loading data for route_id_14306...
# Loading data for route_id_14307...
# Loading data for route_id_14313...
# Loading data for route_id_14314...
# Loading data for route_id_14315...
# Loading data for route_id_14333...
# Loading data for route_id_14339...
# Loading data for route_id_14341...
# Loading data for route_id_14342...
# Loading data for route_id_14354...
# Loading data for route_id_14364...
# Loading data for route_id_14378...
# Loading data for route_id_14379...
# Loading data for route_id_14400...
# Loading data for route_id_14401...
# Loading data for route_id_14402...
# Loading data for route_id_14407...
# Loading data for route_id_14408...
# Loading data for route_id_14416...
# Loading data for route_id_14430...
# Loading data for route_id_14431...
# Loading data for route_id_14435...
# Loading data for route_id_14436...
# Loading data for route_id_14444...
# Loading data for route_id_14445...
# Loading data for route_id_14446...
# Loading data for route_id_14448...
# Loading data for route_id_14449...
# Loading data for route_id_14460...
# Loading data for route_id_14461...
# Loading data for route_id_14462...
# Loading data for route_id_14463...
# Loading data for route_id_14464...
# Loading data for route_id_14467...
# Loading data for route_id_14469...
# Loading data for route_id_14476...
# Loading data for route_id_14478...
# Loading data for route_id_14479...
# Loading data for route_id_14482...
# Loading data for route_id_14485...
# Loading data for route_id_14492...
# Loading data for route_id_14494...
# Loading data for route_id_14495...
# Loading data for route_id_14502...
# Loading data for route_id_14503...
# Loading data for route_id_14508...
# Loading data for route_id_14510...
# Loading data for route_id_14511...
# Loading data for route_id_14512...
# Loading data for route_id_14513...
# Loading data for route_id_14528...
# Loading data for route_id_14529...
# Loading data for route_id_14530...
# Loading data for route_id_14534...
# Loading data for route_id_14540...
# Loading data for route_id_14541...
# Loading data for route_id_14545...
# Loading data for route_id_14548...
# Loading data for route_id_14549...
# Loading data for route_id_14554...
# Loading data for route_id_14555...
# Loading data for route_id_14559...
# Loading data for route_id_14561...
# Loading data for route_id_14562...
# Loading data for route_id_14563...
# Loading data for route_id_14571...
# Loading data for route_id_14574...
# Loading data for route_id_14581...
# Loading data for route_id_14584...
# Loading data for route_id_14585...
# Loading data for route_id_14586...
# Loading data for route_id_14594...
# Loading data for route_id_14595...
# Loading data for route_id_14600...
# Loading data for route_id_14601...
# Loading data for route_id_14616...
# Loading data for route_id_14617...
# Loading data for route_id_14620...
# Loading data for route_id_14621...
# Loading data for route_id_14622...
# Loading data for route_id_14644...
# Loading data for route_id_14654...
# Loading data for route_id_14655...
# Loading data for route_id_14672...
# Loading data for route_id_14673...
# Loading data for route_id_14674...
# Loading data for route_id_14675...
# Loading data for route_id_14676...
# Loading data for route_id_14677...
# Loading data for route_id_14686...
# Loading data for route_id_14687...
# Loading data for route_id_14691...
# Loading data for route_id_14692...
# Loading data for route_id_14693...
# Loading data for route_id_14701...
# Loading data for route_id_14703...
# Loading data for route_id_14704...
# Loading data for route_id_14711...
# Loading data for route_id_14718...
# Loading data for route_id_14719...
# Loading data for route_id_14722...
# Loading data for route_id_14723...
# Loading data for route_id_14729...
# Loading data for route_id_14732...
# Loading data for route_id_14733...
# Loading data for route_id_14734...
# Loading data for route_id_14747...
# Loading data for route_id_14748...
# Loading data for route_id_14754...
# Loading data for route_id_14756...
# Loading data for route_id_14757...
# Loading data for route_id_14758...
# Loading data for route_id_14759...
# Loading data for route_id_14762...
# Loading data for route_id_14766...
# Loading data for route_id_14769...
# Loading data for route_id_14770...
# Loading data for route_id_14771...
# Loading data for route_id_14775...
# Loading data for route_id_14776...
# Loading data for route_id_14794...
# Loading data for route_id_14795...
# Loading data for route_id_14832...
# Loading data for route_id_14833...
# Loading data for route_id_14844...
# Loading data for route_id_14852...
# Loading data for route_id_14872...
# Loading data for route_id_14873...
# Loading data for route_id_14881...
# Loading data for route_id_14883...
# Loading data for route_id_14893...
# Loading data for route_id_14894...
# Loading data for route_id_14897...
# Loading data for route_id_14898...
# Loading data for route_id_14901...
# Loading data for route_id_14902...
# Loading data for route_id_14903...
# Loading data for route_id_14904...
# Loading data for route_id_14906...
# Loading data for route_id_14907...
# Loading data for route_id_14909...
# Loading data for route_id_14910...
# Loading data for route_id_14911...
# Loading data for route_id_14912...
# Loading data for route_id_14917...
# Loading data for route_id_14918...
# Loading data for route_id_14919...
# Loading data for route_id_14921...
# Loading data for route_id_14922...
# Loading data for route_id_14925...
# Loading data for route_id_14927...
# Loading data for route_id_14928...
# Loading data for route_id_14929...
# Loading data for route_id_14930...
# Loading data for route_id_14949...
# Loading data for route_id_14950...
# Loading data for route_id_14952...
# Loading data for route_id_14953...
# Loading data for route_id_14954...
# Loading data for route_id_14966...
# Loading data for route_id_15006...
# Loading data for route_id_15007...
# Loading data for route_id_15008...
# Loading data for route_id_15012...
# Loading data for route_id_15013...
# Loading data for route_id_15024...
# Loading data for route_id_15031...
# Loading data for route_id_15032...
# Loading data for route_id_15033...
# Loading data for route_id_15051...
# Loading data for route_id_15052...
# Loading data for route_id_15053...
# Loading data for route_id_15054...
# Loading data for route_id_15055...
# Loading data for route_id_15065...
# Loading data for route_id_15072...
# Loading data for route_id_15073...
# Loading data for route_id_15081...
# Loading data for route_id_15082...
# Loading data for route_id_15083...
# Loading data for route_id_15084...
# Loading data for route_id_15085...
# Loading data for route_id_15086...
# Loading data for route_id_15087...
# Loading data for route_id_15088...
# Loading data for route_id_15089...
# Loading data for route_id_15092...
# Loading data for route_id_15096...
# Loading data for route_id_15097...
# Loading data for route_id_15100...
# Loading data for route_id_15101...
# Loading data for route_id_15102...
# Loading data for route_id_15110...
# Loading data for route_id_15111...
# Loading data for route_id_15120...
# Loading data for route_id_15121...
# Loading data for route_id_15122...
# Loading data for route_id_15123...
# Loading data for route_id_15130...
# Loading data for route_id_15131...
# Loading data for route_id_15139...
# Loading data for route_id_15141...
# Loading data for route_id_15142...
# Loading data for route_id_15147...
# Loading data for route_id_15148...
# Loading data for route_id_15149...
# Loading data for route_id_15153...
# Loading data for route_id_15154...
# Loading data for route_id_15161...
# Loading data for route_id_15169...
# Loading data for route_id_15179...
# Loading data for route_id_15190...
# Loading data for route_id_15199...
# Loading data for route_id_15200...
# Loading data for route_id_15205...
# Loading data for route_id_15206...
# Loading data for route_id_15219...
# Loading data for route_id_15220...
# Loading data for route_id_15221...
# Loading data for route_id_15223...
# Loading data for route_id_15224...
# Loading data for route_id_15229...
# Loading data for route_id_15252...
# Loading data for route_id_15253...
# Loading data for route_id_15254...
# Loading data for route_id_15255...
# Loading data for route_id_15263...
# Loading data for route_id_15264...
# Loading data for route_id_15265...
# Loading data for route_id_15277...
# Loading data for route_id_15278...
# Loading data for route_id_15279...
# Loading data for route_id_15289...
# Loading data for route_id_15291...
# Loading data for route_id_15292...
# Loading data for route_id_15300...
# Loading data for route_id_15301...
# Loading data for route_id_15306...
# Loading data for route_id_15307...
# Loading data for route_id_15316...
# Loading data for route_id_15317...
# Loading data for route_id_15319...
# Loading data for route_id_15320...
# Loading data for route_id_15323...
# Loading data for route_id_15324...
# Loading data for route_id_15363...
# Loading data for route_id_15366...
# Loading data for route_id_15367...
# Loading data for route_id_15381...
# Loading data for route_id_15389...
# Loading data for route_id_15390...
# Loading data for route_id_15432...
# Loading data for route_id_15441...
# Loading data for route_id_15442...
# Loading data for route_id_15456...
# Loading data for route_id_15464...
# Loading data for route_id_15465...
# Loading data for route_id_15466...
# Loading data for route_id_15472...
# Loading data for route_id_15473...
# Loading data for route_id_15480...
# Loading data for route_id_15481...
# Loading data for route_id_15482...
# Loading data for route_id_15483...
# Loading data for route_id_15486...
# Loading data for route_id_15497...
# Loading data for route_id_15507...
# Loading data for route_id_15526...
# Loading data for route_id_15527...
# Loading data for route_id_15532...
# Loading data for route_id_15534...
# Loading data for route_id_15553...
# Loading data for route_id_15554...
# Loading data for route_id_15555...
# Loading data for route_id_15558...
# Loading data for route_id_15559...
# Loading data for route_id_15569...
# Loading data for route_id_15573...
# Loading data for route_id_15576...
# Loading data for route_id_15667...
# Loading data for route_id_15669...
# Loading data for route_id_15679...
# Loading data for route_id_15680...
# Loading data for route_id_15681...
# Loading data for route_id_15686...
# Loading data for route_id_15687...
# Loading data for route_id_15690...
# Loading data for route_id_15697...
# Loading data for route_id_15707...
# Loading data for route_id_15709...
# Loading data for route_id_15711...
# Loading data for route_id_15722...
# Loading data for route_id_15724...
# Loading data for route_id_15727...
# Loading data for route_id_15728...
# Loading data for route_id_15729...
# Loading data for route_id_15730...
# Loading data for route_id_15731...
# Loading data for route_id_15732...
# Loading data for route_id_15733...
# Loading data for route_id_15734...
# Loading data for route_id_15735...
# Loading data for route_id_15736...
# Loading data for route_id_15737...
# Loading data for route_id_15739...
# Loading data for route_id_15740...
# Loading data for route_id_15741...
# Loading data for route_id_15742...
# Loading data for route_id_15751...
# Loading data for route_id_15752...
# Loading data for route_id_15753...
# Loading data for route_id_15754...
# Loading data for route_id_15756...
# Loading data for route_id_15757...
# Loading data for route_id_15758...
# Loading data for route_id_15759...
# Loading data for route_id_15762...
# Loading data for route_id_15765...
# Loading data for route_id_15769...
# Loading data for route_id_15777...
# Loading data for route_id_15792...
# Loading data for route_id_15793...
# Loading data for route_id_15796...
# Loading data for route_id_15797...
# Loading data for route_id_15801...
# Loading data for route_id_15803...
# Loading data for route_id_15804...
# Loading data for route_id_15810...
# Loading data for route_id_15811...
# Loading data for route_id_15812...
# Loading data for route_id_15813...
# Loading data for route_id_15815...
# Loading data for route_id_15816...
# Loading data for route_id_15817...
# Loading data for route_id_15818...
# Loading data for route_id_15819...
# Loading data for route_id_15820...
# Loading data for route_id_15821...
# Loading data for route_id_15822...
# Loading data for route_id_15823...
# Loading data for route_id_15824...
# Loading data for route_id_15828...
# Loading data for route_id_15829...
# Loading data for route_id_15830...
# Loading data for route_id_15831...
# Loading data for route_id_15834...
# Loading data for route_id_15835...
# Loading data for route_id_15854...
# Loading data for route_id_15855...
# Loading data for route_id_15856...
# Loading data for route_id_15857...
# Loading data for route_id_15859...
# Loading data for route_id_15860...
# Loading data for route_id_15861...
# Loading data for route_id_15862...
# Loading data for route_id_15863...
# Loading data for route_id_15866...
# Loading data for route_id_15867...
# Loading data for route_id_15868...
# Loading data for route_id_15869...
# Loading data for route_id_15872...
# Loading data for route_id_15876...
# Loading data for route_id_15877...
# Loading data for route_id_15878...
# Loading data for route_id_15882...
# Loading data for route_id_15883...
# Loading data for route_id_15886...
# Loading data for route_id_15887...
# Loading data for route_id_15888...
# Loading data for route_id_15889...
# Loading data for route_id_15890...
# Loading data for route_id_15891...
# Loading data for route_id_15892...
# Loading data for route_id_15893...
# Loading data for route_id_15921...
# Loading data for route_id_15922...
# Loading data for route_id_15923...
# Loading data for route_id_15926...
# Loading data for route_id_15929...
# Loading data for route_id_15930...
# Loading data for route_id_15934...
# Loading data for route_id_15935...
# Loading data for route_id_15937...
# Loading data for route_id_15938...
# Loading data for route_id_15940...
# Loading data for route_id_15941...
# Loading data for route_id_15942...
# Loading data for route_id_15943...
# Loading data for route_id_15944...
# Loading data for route_id_15947...
# Loading data for route_id_15948...
# Loading data for route_id_15949...
# Loading data for route_id_15950...
# Loading data for route_id_15955...
# Loading data for route_id_15959...
# Loading data for route_id_15981...
# Loading data for route_id_15982...
# Loading data for route_id_15989...
# Loading data for route_id_15990...
# Loading data for route_id_15997...
# Loading data for route_id_16000...
# Loading data for route_id_16003...
# Loading data for route_id_16015...
# Loading data for route_id_16016...
# Loading data for route_id_16017...
# Loading data for route_id_16018...
# Loading data for route_id_16047...
# Loading data for route_id_16048...
# Loading data for route_id_16059...
# Loading data for route_id_16060...
# Loading data for route_id_16069...
# Loading data for route_id_16070...
# Loading data for route_id_16071...
# Loading data for route_id_16072...
# Loading data for route_id_16077...
# Loading data for route_id_16080...
# Loading data for route_id_16081...
# Loading data for route_id_16089...
# Loading data for route_id_16091...
# Loading data for route_id_16092...
# Loading data for route_id_16096...
# Loading data for route_id_16097...
# Loading data for route_id_16099...
# Loading data for route_id_16100...
# Loading data for route_id_16101...
# Loading data for route_id_16105...
# Loading data for route_id_16106...
# Loading data for route_id_16107...
# Loading data for route_id_16108...
# Loading data for route_id_16109...
# Loading data for route_id_16118...
# Loading data for route_id_16119...
# Loading data for route_id_16122...
# Loading data for route_id_16123...
# Loading data for route_id_16124...
# Loading data for route_id_16125...
# Loading data for route_id_16148...
# Loading data for route_id_16154...
# Loading data for route_id_1657...
# Loading data for route_id_1658...
# Loading data for route_id_1659...
# Loading data for route_id_1660...
# Loading data for route_id_1661...
# Loading data for route_id_1662...
# Loading data for route_id_1663...
# Loading data for route_id_1664...
# Loading data for route_id_1665...
# Loading data for route_id_1666...
# Loading data for route_id_1667...
# Loading data for route_id_1668...
# Loading data for route_id_1669...
# Loading data for route_id_1670...
# Loading data for route_id_1671...
# Loading data for route_id_1672...
# Loading data for route_id_1673...
# Loading data for route_id_1674...
# Loading data for route_id_1675...
# Loading data for route_id_1676...
# Loading data for route_id_1677...
# Loading data for route_id_1678...
# Loading data for route_id_1679...
# Loading data for route_id_1680...
# Loading data for route_id_1682...
# Loading data for route_id_1683...
# Loading data for route_id_1684...
# Loading data for route_id_1685...
# Loading data for route_id_1686...
# Loading data for route_id_1687...
# Loading data for route_id_1688...
# Loading data for route_id_1689...
# Loading data for route_id_1690...
# Loading data for route_id_1691...
# Loading data for route_id_1692...
# Loading data for route_id_1693...
# Loading data for route_id_1698...
# Loading data for route_id_1699...
# Loading data for route_id_1700...
# Loading data for route_id_1701...
# Loading data for route_id_1702...
# Loading data for route_id_1703...
# Loading data for route_id_1704...
# Loading data for route_id_1705...
# Loading data for route_id_1708...
# Loading data for route_id_1709...
# Loading data for route_id_1710...
# Loading data for route_id_1711...
# Loading data for route_id_1712...
# Loading data for route_id_1713...
# Loading data for route_id_1714...
# Loading data for route_id_1715...
# Loading data for route_id_1716...
# Loading data for route_id_1717...
# Loading data for route_id_1718...
# Loading data for route_id_1719...
# Loading data for route_id_1720...
# Loading data for route_id_1721...
# Loading data for route_id_1724...
# Loading data for route_id_1725...
# Loading data for route_id_1726...
# Loading data for route_id_1728...
# Loading data for route_id_1729...
# Loading data for route_id_1730...
# Loading data for route_id_1731...
# Loading data for route_id_1732...
# Loading data for route_id_1733...
# Loading data for route_id_1734...
# Loading data for route_id_1736...
# Loading data for route_id_1737...
# Loading data for route_id_1740...
# Loading data for route_id_1741...
# Loading data for route_id_1742...
# Loading data for route_id_1743...
# Loading data for route_id_1746...
# Loading data for route_id_1747...
# Loading data for route_id_1748...
# Loading data for route_id_1749...
# Loading data for route_id_1751...
# Loading data for route_id_1752...
# Loading data for route_id_1753...
# Loading data for route_id_1754...
# Loading data for route_id_1755...
# Loading data for route_id_1761...
# Loading data for route_id_1764...
# Loading data for route_id_1765...
# Loading data for route_id_1766...
# Loading data for route_id_1770...
# Loading data for route_id_1771...
# Loading data for route_id_1772...
# Loading data for route_id_1773...
# Loading data for route_id_1774...
# Loading data for route_id_1775...
# Loading data for route_id_1791...
# Loading data for route_id_1792...
# Loading data for route_id_1793...
# Loading data for route_id_1794...
# Loading data for route_id_1795...
# Loading data for route_id_1796...
# Loading data for route_id_1800...
# Loading data for route_id_1801...
# Loading data for route_id_1802...
# Loading data for route_id_1803...
# Loading data for route_id_1804...
# Loading data for route_id_1805...
# Loading data for route_id_1806...
# Loading data for route_id_1807...
# Loading data for route_id_1809...
# Loading data for route_id_1812...
# Loading data for route_id_1813...
# Loading data for route_id_1814...
# Loading data for route_id_1815...
# Loading data for route_id_1817...
# Loading data for route_id_1818...
# Loading data for route_id_1822...
# Loading data for route_id_1823...
# Loading data for route_id_1824...
# Loading data for route_id_1827...
# Loading data for route_id_1829...
# Loading data for route_id_1830...
# Loading data for route_id_1835...
# Loading data for route_id_1839...
# Loading data for route_id_1840...
# Loading data for route_id_1842...
# Loading data for route_id_1843...
# Loading data for route_id_1846...
# Loading data for route_id_1849...
# Loading data for route_id_1850...
# Loading data for route_id_1853...
# Loading data for route_id_1854...
# Loading data for route_id_1855...
# Loading data for route_id_1856...
# Loading data for route_id_1857...
# Loading data for route_id_1858...
# Loading data for route_id_1859...
# Loading data for route_id_1860...
# Loading data for route_id_1861...
# Loading data for route_id_1862...
# Loading data for route_id_1863...
# Loading data for route_id_1864...
# Loading data for route_id_1865...
# Loading data for route_id_1866...
# Loading data for route_id_1868...
# Loading data for route_id_1869...
# Loading data for route_id_1874...
# Loading data for route_id_1877...
# Loading data for route_id_1878...
# Loading data for route_id_1879...
# Loading data for route_id_1881...
# Loading data for route_id_1882...
# Loading data for route_id_1884...
# Loading data for route_id_1885...
# Loading data for route_id_1886...
# Loading data for route_id_1887...
# Loading data for route_id_1888...
# Loading data for route_id_1890...
# Loading data for route_id_1891...
# Loading data for route_id_1892...
# Loading data for route_id_1893...
# Loading data for route_id_1894...
# Loading data for route_id_1900...
# Loading data for route_id_1903...
# Loading data for route_id_1906...
# Loading data for route_id_1907...
# Loading data for route_id_1910...
# Loading data for route_id_1911...
# Loading data for route_id_1912...
# Loading data for route_id_1916...
# Loading data for route_id_1917...
# Loading data for route_id_1918...
# Loading data for route_id_1919...
# Loading data for route_id_1920...
# Loading data for route_id_1921...
# Loading data for route_id_1922...
# Loading data for route_id_1923...
# Loading data for route_id_1924...
# Loading data for route_id_1934...
# Loading data for route_id_1935...
# Loading data for route_id_1936...
# Loading data for route_id_1937...
# Loading data for route_id_1938...
# Loading data for route_id_1939...
# Loading data for route_id_1940...
# Loading data for route_id_1941...
# Loading data for route_id_1942...
# Loading data for route_id_1947...
# Loading data for route_id_1948...
# Loading data for route_id_1951...
# Loading data for route_id_1952...
# Loading data for route_id_1961...
# Loading data for route_id_1962...
# Loading data for route_id_1963...
# Loading data for route_id_1964...
# Loading data for route_id_1967...
# Loading data for route_id_1968...
# Loading data for route_id_1969...
# Loading data for route_id_1970...
# Loading data for route_id_1974...
# Loading data for route_id_1975...
# Loading data for route_id_1978...
# Loading data for route_id_1979...
# Loading data for route_id_1980...
# Loading data for route_id_1981...
# Loading data for route_id_1982...
# Loading data for route_id_1983...
# Loading data for route_id_1984...
# Loading data for route_id_1985...
# Loading data for route_id_1986...
# Loading data for route_id_1987...
# Loading data for route_id_1988...
# Loading data for route_id_1989...
# Loading data for route_id_1990...
# Loading data for route_id_1993...
# Loading data for route_id_1994...
# Loading data for route_id_1995...
# Loading data for route_id_1996...
# Loading data for route_id_1997...
# Loading data for route_id_1998...
# Loading data for route_id_1999...
# Loading data for route_id_2000...
# Loading data for route_id_2001...
# Loading data for route_id_2002...
# Loading data for route_id_2003...
# Loading data for route_id_2004...
# Loading data for route_id_2005...
# Loading data for route_id_2006...
# Loading data for route_id_2007...
# Loading data for route_id_2013...
# Loading data for route_id_2018...
# Loading data for route_id_2021...
# Loading data for route_id_2023...
# Loading data for route_id_2024...
# Loading data for route_id_2025...
# Loading data for route_id_2037...
# Loading data for route_id_2038...
# Loading data for route_id_2039...
# Loading data for route_id_2040...
# Loading data for route_id_2041...
# Loading data for route_id_2042...
# Loading data for route_id_2043...
# Loading data for route_id_2044...
# Loading data for route_id_2045...
# Loading data for route_id_2046...
# Loading data for route_id_2049...
# Loading data for route_id_2050...
# Loading data for route_id_2055...
# Loading data for route_id_2056...
# Loading data for route_id_2057...
# Loading data for route_id_2058...
# Loading data for route_id_2061...
# Loading data for route_id_2062...
# Loading data for route_id_2063...
# Loading data for route_id_2064...
# Loading data for route_id_2070...
# Loading data for route_id_2071...
# Loading data for route_id_2072...
# Loading data for route_id_2073...
# Loading data for route_id_2086...
# Loading data for route_id_2088...
# Loading data for route_id_2089...
# Loading data for route_id_2092...
# Loading data for route_id_2094...
# Loading data for route_id_2095...
# Loading data for route_id_2098...
# Loading data for route_id_2099...
# Loading data for route_id_2100...
# Loading data for route_id_2101...
# Loading data for route_id_2104...
# Loading data for route_id_2105...
# Loading data for route_id_2108...
# Loading data for route_id_2109...
# Loading data for route_id_2112...
# Loading data for route_id_2113...
# Loading data for route_id_2116...
# Loading data for route_id_2120...
# Loading data for route_id_2123...
# Loading data for route_id_2131...
# Loading data for route_id_2134...
# Loading data for route_id_2136...
# Loading data for route_id_2137...
# Loading data for route_id_2138...
# Loading data for route_id_2139...
# Loading data for route_id_2140...
# Loading data for route_id_2143...
# Loading data for route_id_2145...
# Loading data for route_id_2146...
# Loading data for route_id_2150...
# Loading data for route_id_2151...
# Loading data for route_id_2152...
# Loading data for route_id_2153...
# Loading data for route_id_2154...
# Loading data for route_id_2155...
# Loading data for route_id_2156...
# Loading data for route_id_2157...
# Loading data for route_id_2158...
# Loading data for route_id_2159...
# Loading data for route_id_2160...
# Loading data for route_id_2161...
# Loading data for route_id_2162...
# Loading data for route_id_2164...
# Loading data for route_id_2166...
# Loading data for route_id_2168...
# Loading data for route_id_2174...
# Loading data for route_id_2176...
# Loading data for route_id_2179...
# Loading data for route_id_2180...
# Loading data for route_id_2182...
# Loading data for route_id_2183...
# Loading data for route_id_2185...
# Loading data for route_id_2186...
# Loading data for route_id_2187...
# Loading data for route_id_2188...
# Loading data for route_id_2189...
# Loading data for route_id_2190...
# Loading data for route_id_2191...
# Loading data for route_id_2192...
# Loading data for route_id_2196...
# Loading data for route_id_2202...
# Loading data for route_id_2208...
# Loading data for route_id_2211...
# Loading data for route_id_2214...
# Loading data for route_id_2216...
# Loading data for route_id_2217...
# Loading data for route_id_2220...
# ...
# Loading data for route_id_7735...
# Loading data for route_id_7736...
# Loading data for route_id_7738...
# Loading data for route_id_7751...
# Loading data for route_id_7752...
# Loading data for route_id_7754...
# Loading data for route_id_7764...
# Loading data for route_id_7790...
# Loading data for route_id_7795...
# Loading data for route_id_7798...
# Loading data for route_id_7799...
# Loading data for route_id_7806...
# Loading data for route_id_7808...
# Loading data for route_id_7838...
# Loading data for route_id_7839...
# Loading data for route_id_7840...
# Loading data for route_id_7845...
# Loading data for route_id_7856...
# Loading data for route_id_7859...
# Loading data for route_id_7865...
# Loading data for route_id_7881...
# Loading data for route_id_7885...
# Loading data for route_id_7886...
# Loading data for route_id_7887...
# Loading data for route_id_7891...
# Loading data for route_id_7897...
# Loading data for route_id_7899...
# Loading data for route_id_7902...
# Loading data for route_id_7911...
# Loading data for route_id_7912...
# Loading data for route_id_7919...
# Loading data for route_id_7922...
# Loading data for route_id_7923...
# Loading data for route_id_7939...
# Loading data for route_id_7941...
# Loading data for route_id_7942...
# Loading data for route_id_7944...
# Loading data for route_id_7950...
# Loading data for route_id_7952...
# Loading data for route_id_7961...
# Loading data for route_id_7962...
# Loading data for route_id_7963...
# Loading data for route_id_7968...
# Loading data for route_id_7970...
# Loading data for route_id_7971...
# Loading data for route_id_7972...
# Loading data for route_id_7973...
# Loading data for route_id_7976...
# Loading data for route_id_7990...
# Loading data for route_id_7997...
# Loading data for route_id_8000...
# Loading data for route_id_8002...
# Loading data for route_id_8005...
# Loading data for route_id_8008...
# Loading data for route_id_8010...
# Loading data for route_id_8012...
# Loading data for route_id_8016...
# Loading data for route_id_8017...
# Loading data for route_id_8018...
# Loading data for route_id_8021...
# Loading data for route_id_8026...
# Loading data for route_id_8027...
# Loading data for route_id_8029...
# Loading data for route_id_8051...
# Loading data for route_id_8057...
# Loading data for route_id_8059...
# Loading data for route_id_8060...
# Loading data for route_id_8061...
# Loading data for route_id_8089...
# Loading data for route_id_8091...
# Loading data for route_id_8093...
# Loading data for route_id_8094...
# Loading data for route_id_8100...
# Loading data for route_id_8102...
# Loading data for route_id_8113...
# Loading data for route_id_8119...
# Loading data for route_id_8120...
# Loading data for route_id_8121...
# Loading data for route_id_8130...
# Loading data for route_id_8134...
# Loading data for route_id_8135...
# Loading data for route_id_8140...
# Loading data for route_id_8146...
# Loading data for route_id_8147...
# Loading data for route_id_8148...
# Loading data for route_id_8149...
# Loading data for route_id_8165...
# Loading data for route_id_8166...
# Loading data for route_id_8169...
# Loading data for route_id_8179...
# Loading data for route_id_8181...
# Loading data for route_id_8184...
# Loading data for route_id_8185...
# Loading data for route_id_8190...
# Loading data for route_id_8191...
# Loading data for route_id_8192...
# Loading data for route_id_8193...
# Loading data for route_id_8194...
# Loading data for route_id_8195...
# Loading data for route_id_8196...
# Loading data for route_id_8201...
# Loading data for route_id_8204...
# Loading data for route_id_8209...
# Loading data for route_id_8214...
# Loading data for route_id_8216...
# Loading data for route_id_8217...
# Loading data for route_id_8219...
# Loading data for route_id_8224...
# Loading data for route_id_8225...
# Loading data for route_id_8253...
# Loading data for route_id_8267...
# Loading data for route_id_8268...
# Loading data for route_id_8269...
# Loading data for route_id_8274...
# Loading data for route_id_8275...
# Loading data for route_id_8277...
# Loading data for route_id_8278...
# Loading data for route_id_8279...
# Loading data for route_id_8281...
# Loading data for route_id_8291...
# Loading data for route_id_8295...
# Loading data for route_id_8296...
# Loading data for route_id_8300...
# Loading data for route_id_8304...
# Loading data for route_id_8305...
# Loading data for route_id_8306...
# Loading data for route_id_8307...
# Loading data for route_id_8325...
# Loading data for route_id_8327...
# Loading data for route_id_8332...
# Loading data for route_id_8334...
# Loading data for route_id_8349...
# Loading data for route_id_8351...
# Loading data for route_id_8357...
# Loading data for route_id_8358...
# Loading data for route_id_8365...
# Loading data for route_id_8376...
# Loading data for route_id_8395...
# Loading data for route_id_8396...
# Loading data for route_id_8397...
# Loading data for route_id_8399...
# Loading data for route_id_8400...
# Loading data for route_id_8412...
# Loading data for route_id_8414...
# Loading data for route_id_8416...
# Loading data for route_id_8422...
# Loading data for route_id_8423...
# Loading data for route_id_8424...
# Loading data for route_id_8429...
# Loading data for route_id_8460...
# Loading data for route_id_8461...
# Loading data for route_id_8462...
# Loading data for route_id_8464...
# Loading data for route_id_8465...
# Loading data for route_id_8466...
# Loading data for route_id_8513...
# Loading data for route_id_8514...
# Loading data for route_id_8527...
# Loading data for route_id_8528...
# Loading data for route_id_8534...
# Loading data for route_id_8536...
# Loading data for route_id_8538...
# Loading data for route_id_8540...
# Loading data for route_id_8541...
# Loading data for route_id_8547...
# Loading data for route_id_8548...
# Loading data for route_id_8581...
# Loading data for route_id_8582...
# Loading data for route_id_8602...
# Loading data for route_id_8605...
# Loading data for route_id_8608...
# Loading data for route_id_8613...
# Loading data for route_id_8618...
# Loading data for route_id_8621...
# Loading data for route_id_8622...
# Loading data for route_id_8629...
# Loading data for route_id_8630...
# Loading data for route_id_8631...
# Loading data for route_id_8632...
# Loading data for route_id_8633...
# Loading data for route_id_8655...
# Loading data for route_id_8656...
# Loading data for route_id_8690...
# Loading data for route_id_8693...
# Loading data for route_id_8707...
# Loading data for route_id_8743...
# Loading data for route_id_8778...
# Loading data for route_id_8790...
# Loading data for route_id_8809...
# Loading data for route_id_8811...
# Loading data for route_id_8817...
# Loading data for route_id_8820...
# Loading data for route_id_8828...
# Loading data for route_id_8847...
# Loading data for route_id_8848...
# Loading data for route_id_8861...
# Loading data for route_id_8862...
# Loading data for route_id_8865...
# Loading data for route_id_8867...
# Loading data for route_id_8869...
# Loading data for route_id_8873...
# Loading data for route_id_8875...
# Loading data for route_id_8877...
# Loading data for route_id_8889...
# Loading data for route_id_8890...
# Loading data for route_id_8891...
# Loading data for route_id_8898...
# Loading data for route_id_8903...
# Loading data for route_id_8907...
# Loading data for route_id_8908...
# Loading data for route_id_8909...
# Loading data for route_id_8912...
# Loading data for route_id_8913...
# Loading data for route_id_8914...
# Loading data for route_id_8925...
# Loading data for route_id_8927...
# Loading data for route_id_8960...
# Loading data for route_id_8967...
# Loading data for route_id_8968...
# Loading data for route_id_8969...
# Loading data for route_id_8971...
# Loading data for route_id_8974...
# Loading data for route_id_8975...
# Loading data for route_id_8977...
# Loading data for route_id_8978...
# Loading data for route_id_8989...
# Loading data for route_id_8990...
# Loading data for route_id_8991...
# Loading data for route_id_8992...
# Loading data for route_id_8995...
# Loading data for route_id_8996...
# Loading data for route_id_8998...
# Loading data for route_id_9001...
# Loading data for route_id_9004...
# Loading data for route_id_9005...
# Loading data for route_id_9011...
# Loading data for route_id_9012...
# Loading data for route_id_9015...
# Loading data for route_id_9028...
# Loading data for route_id_9030...
# Loading data for route_id_9032...
# Loading data for route_id_9033...
# Loading data for route_id_9040...
# Loading data for route_id_9049...
# Loading data for route_id_9052...
# Loading data for route_id_9056...
# Loading data for route_id_9057...
# Loading data for route_id_9064...
# Loading data for route_id_9065...
# Loading data for route_id_9067...
# Loading data for route_id_9068...
# Loading data for route_id_9070...
# Loading data for route_id_9071...
# Loading data for route_id_9076...
# Loading data for route_id_9077...
# Loading data for route_id_9078...
# Loading data for route_id_9083...
# Loading data for route_id_9085...
# Loading data for route_id_9087...
# Loading data for route_id_9088...
# Loading data for route_id_9089...
# Loading data for route_id_9091...
# Loading data for route_id_9101...
# Loading data for route_id_9103...
# Loading data for route_id_9104...
# Loading data for route_id_9106...
# Loading data for route_id_9113...
# Loading data for route_id_9117...
# Loading data for route_id_9118...
# Loading data for route_id_9131...
# Loading data for route_id_9132...
# Loading data for route_id_9133...
# Loading data for route_id_9134...
# Loading data for route_id_9145...
# Loading data for route_id_9146...
# Loading data for route_id_9149...
# Loading data for route_id_9150...
# Loading data for route_id_9151...
# Loading data for route_id_9173...
# Loading data for route_id_9174...
# Loading data for route_id_9176...
# Loading data for route_id_9180...
# Loading data for route_id_9199...
# Loading data for route_id_9201...
# Loading data for route_id_9206...
# Loading data for route_id_9208...
# Loading data for route_id_9215...
# Loading data for route_id_9222...
# Loading data for route_id_9241...
# Loading data for route_id_9248...
# Loading data for route_id_9251...
# Loading data for route_id_9277...
# Loading data for route_id_9278...
# Loading data for route_id_9279...
# Loading data for route_id_9280...
# Loading data for route_id_9284...
# Loading data for route_id_9286...
# Loading data for route_id_9288...
# Loading data for route_id_9291...
# Loading data for route_id_9292...
# Loading data for route_id_9293...
# Loading data for route_id_9303...
# Loading data for route_id_9304...
# Loading data for route_id_9306...
# Loading data for route_id_9309...
# Loading data for route_id_9313...
# Loading data for route_id_9314...
# Loading data for route_id_9316...
# Loading data for route_id_9324...
# Loading data for route_id_9326...
# Loading data for route_id_9328...
# Loading data for route_id_9330...
# Loading data for route_id_9347...
# Loading data for route_id_9350...
# Loading data for route_id_9356...
# Loading data for route_id_9357...
# Loading data for route_id_9358...
# Loading data for route_id_9361...
# Loading data for route_id_9362...
# Loading data for route_id_9363...
# Loading data for route_id_9364...
# Loading data for route_id_9373...
# Loading data for route_id_9374...
# Loading data for route_id_9375...
# Loading data for route_id_9376...
# Loading data for route_id_9392...
# Loading data for route_id_9393...
# Loading data for route_id_9397...
# Loading data for route_id_9399...
# Loading data for route_id_9401...
# Loading data for route_id_9402...
# Loading data for route_id_9405...
# Loading data for route_id_9408...
# Loading data for route_id_9415...
# Loading data for route_id_9416...
# Loading data for route_id_9417...
# Loading data for route_id_9418...
# Loading data for route_id_9419...
# Loading data for route_id_9420...
# Loading data for route_id_9441...
# Loading data for route_id_9449...
# Loading data for route_id_9450...
# Loading data for route_id_9463...
# Loading data for route_id_9465...
# Loading data for route_id_9468...
# Loading data for route_id_9469...
# Loading data for route_id_9472...
# Loading data for route_id_9496...
# Loading data for route_id_9497...
# Loading data for route_id_9498...
# Loading data for route_id_9504...
# Loading data for route_id_9508...
# Loading data for route_id_9509...
# Loading data for route_id_9513...
# Loading data for route_id_9514...
# Loading data for route_id_9515...
# Loading data for route_id_9516...
# Loading data for route_id_9525...
# Loading data for route_id_9526...
# Loading data for route_id_9536...
# Loading data for route_id_9537...
# Loading data for route_id_9539...
# Loading data for route_id_9540...
# Loading data for route_id_9541...
# Loading data for route_id_9542...
# Loading data for route_id_9545...
# Loading data for route_id_9546...
# Loading data for route_id_9547...
# Loading data for route_id_9548...
# Loading data for route_id_9551...
# Loading data for route_id_9553...
# Loading data for route_id_9559...
# Loading data for route_id_9562...
# Loading data for route_id_9564...
# Loading data for route_id_9566...
# Loading data for route_id_9567...
# Loading data for route_id_9570...
# Loading data for route_id_9571...
# Loading data for route_id_9572...
# Loading data for route_id_9573...
# Loading data for route_id_9575...
# Loading data for route_id_9576...
# Loading data for route_id_9578...
# Loading data for route_id_9581...
# Loading data for route_id_9582...
# Loading data for route_id_9595...
# Loading data for route_id_9615...
# Loading data for route_id_9622...
# Loading data for route_id_9623...
# Loading data for route_id_9626...
# Loading data for route_id_9630...
# Loading data for route_id_9631...
# Loading data for route_id_9633...
# Loading data for route_id_9637...
# Loading data for route_id_9638...
# Loading data for route_id_9645...
# Loading data for route_id_9646...
# Loading data for route_id_9650...
# Loading data for route_id_9655...
# Loading data for route_id_9656...
# Loading data for route_id_9657...
# Loading data for route_id_9658...
# Loading data for route_id_9659...
# Loading data for route_id_9662...
# Loading data for route_id_9663...
# Loading data for route_id_9665...
# Loading data for route_id_9666...
# Loading data for route_id_9667...
# Loading data for route_id_9668...
# Loading data for route_id_9673...
# Loading data for route_id_9675...
# Loading data for route_id_9676...
# Loading data for route_id_9679...
# Loading data for route_id_9685...
# Loading data for route_id_9686...
# Loading data for route_id_9687...
# Loading data for route_id_9691...
# Loading data for route_id_9692...
# Loading data for route_id_9694...
# Loading data for route_id_9706...
# Loading data for route_id_9709...
# Loading data for route_id_9713...
# Loading data for route_id_9722...
# Loading data for route_id_9723...
# Loading data for route_id_9776...
# Loading data for route_id_9778...
# Loading data for route_id_9800...
# Loading data for route_id_9801...
# Loading data for route_id_9818...
# Loading data for route_id_9836...
# Loading data for route_id_9842...
# Loading data for route_id_9843...
# Loading data for route_id_9868...
# Loading data for route_id_9869...
# Loading data for route_id_9870...
# Loading data for route_id_9871...
# Loading data for route_id_9889...
# Loading data for route_id_9891...
# Loading data for route_id_9892...
# Loading data for route_id_9901...
# Loading data for route_id_9909...
# Loading data for route_id_9912...
# Loading data for route_id_9913...
# Loading data for route_id_9914...
# Loading data for route_id_9915...
# Loading data for route_id_9916...
# Loading data for route_id_9917...
# Loading data for route_id_9920...
# Loading data for route_id_9921...
# Loading data for route_id_9930...
# Loading data for route_id_9939...
# Loading data for route_id_9940...
# Loading data for route_id_9949...
# Loading data for route_id_9950...
# Loading data for route_id_9953...
# Loading data for route_id_9954...
# Loading data for route_id_9961...
# Loading data for route_id_9962...
# Loading data for route_id_9963...
# Loading data for route_id_9964...
# Loading data for route_id_9971...
# Loading data for route_id_9972...
# Loading data for route_id_9973...
# Loading data for route_id_9975...
# Loading data for route_id_9976...
# Loading data for route_id_9983...
# Loading data for route_id_9984...
# Loading data for route_id_9986...
# Loading data for route_id_9997...
# Loading data for route_id_9998...

# %%
combined_df.duplicated().sum() # no duplicates
# Out:
# np.int64(0)

# %%
#cleaning of trips

# %%
df_stops = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\Bengaluru Vega\Code\task_1\ref_data\stops_0.csv")
route_to_stop_sequence = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\Bengaluru Vega\Code\task_1\ref_data\route_to_stop_sequence_v2.csv")

# %%
import pandas as pd
import numpy as np
import ast
from tqdm import tqdm
from math import radians, sin, cos, atan2, sqrt

# -------------------------
# Utilities
# -------------------------
def haversine_vectorized(lat1, lon1, lat2, lon2):
    """
    Vectorized haversine:
      - lat1, lon1 : 1D arrays of shape (m,)
      - lat2, lon2 : 1D arrays of shape (n,)
    Returns (m, n) array of distances in meters.
    """
    R = 6371000.0  # Earth radius in meters
    lat1r = np.radians(lat1)[:, None]    # (m,1)
    lon1r = np.radians(lon1)[:, None]
    lat2r = np.radians(lat2)[None, :]    # (1,n)
    lon2r = np.radians(lon2)[None, :]

    dlat = lat2r - lat1r
    dlon = lon2r - lon1r

    a = np.sin(dlat / 2.0) ** 2 + np.cos(lat1r) * np.cos(lat2r) * np.sin(dlon / 2.0) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c  # (m,n)

def haversine_point(lat1, lon1, lat2, lon2):
    """Single-point haversine in meters (lat/lon scalars)."""
    R = 6371000.0
    phi1, phi2 = radians(lat1), radians(lat2)
    dphi = radians(lat2 - lat1)
    dlambda = radians(lon2 - lon1)
    a = sin(dphi/2)**2 + cos(phi1)*cos(phi2)*sin(dlambda/2)**2
    return 2*R*atan2(sqrt(a), sqrt(1-a))

def parse_stop_seq_field(val):
    """Safely parse stop_id_list which may be a string like "['123','456']" or already a list."""
    if isinstance(val, list):
        return [int(x) for x in val]
    if pd.isna(val):
        return []
    if isinstance(val, str):
        # try literal_eval first
        try:
            parsed = ast.literal_eval(val)
            return [int(x) for x in parsed]
        except Exception:
            # fallback: crude split
            s = val.strip()
            if s.startswith('[') and s.endswith(']'):
                s = s[1:-1]
            parts = [p.strip().strip("'\"") for p in s.split(",") if p.strip()]
            return [int(x) for x in parts]
    raise ValueError("Unsupported stop_id_list format")

# -------------------------
# Normalizers
# -------------------------
def normalize_live_df(df):
    df = df.copy()
    # rename common variations
    rename_map = {}
    if 'lat' in df.columns and 'latitude' not in df.columns: rename_map['lat'] = 'latitude'
    if 'lon' in df.columns and 'longitude' not in df.columns: rename_map['lon'] = 'longitude'
    if 'long' in df.columns and 'longitude' not in df.columns: rename_map['long'] = 'longitude'
    if 'timestamp' in df.columns and 'vehicle_timestamp' not in df.columns: rename_map['timestamp'] = 'vehicle_timestamp'
    if rename_map:
        df = df.rename(columns=rename_map)

    # required columns
    required = ['trip_id','route_id','vehicle_timestamp','latitude','longitude']
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"live_df missing required columns: {missing}")

    # parse route_id/trip_id to ints (if possible)
    try:
        df['route_id'] = df['route_id'].astype(int)
    except Exception:
        pass

    # parse vehicle_timestamp robustly:
    ts = df['vehicle_timestamp']
    if np.issubdtype(ts.dtype, np.number):
        df['vehicle_timestamp'] = pd.to_datetime(ts, unit='s', errors='coerce')
    else:
        parsed = pd.to_datetime(ts, errors='coerce')
        # if too many NaT, try numeric->unit seconds
        if parsed.isna().mean() > 0.5:
            try:
                df['vehicle_timestamp'] = pd.to_datetime(ts.astype(float), unit='s', errors='coerce')
            except Exception:
                df['vehicle_timestamp'] = parsed
        else:
            df['vehicle_timestamp'] = parsed

    # drop rows with no parsed timestamp or lat/lon
    df = df.dropna(subset=['vehicle_timestamp','latitude','longitude']).reset_index(drop=True)
    return df

def normalize_stops_df(stops_df):
    df = stops_df.copy()
    rename_map = {}
    if 'stop_lat' not in df.columns and 'latitude' in df.columns: rename_map['latitude'] = 'stop_lat'
    if 'stop_lon' not in df.columns and 'longitude' in df.columns: rename_map['longitude'] = 'stop_lon'
    if rename_map:
        df = df.rename(columns=rename_map)
    required = ['stop_id','stop_lat','stop_lon']
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"stops_df missing required columns: {missing}")
    df['stop_id'] = df['stop_id'].astype(int)
    return df

# -------------------------
# Find entry/exit pings (vectorized-friendly)
# -------------------------
def find_entry_exit_pings_trip_sorted(trip_df_sorted, stop_lat, stop_lon, radius=50):
    """
    Given a trip's pings (sorted by vehicle_timestamp), return (before, after)
      - before: last ping before entering radius (or first inside if nothing before)
      - after : first ping after leaving radius (or last inside if nothing after)
    If no inside pings, returns (None, None).
    """
    # use numpy vectorized haversine to compute distances to the single stop
    lats = trip_df_sorted['latitude'].values
    lons = trip_df_sorted['longitude'].values
    # compute distances to the single point (fast)
    dists = haversine_vectorized(lats, lons, np.array([stop_lat]), np.array([stop_lon])).ravel()  # shape (m,)
    inside_mask = dists <= radius
    if not inside_mask.any():
        return None, None
    idxs = np.where(inside_mask)[0]
    idx_first = idxs[0]
    idx_last = idxs[-1]

    # before = ping just before entering (if exists), else first inside
    before_idx = idx_first - 1 if idx_first - 1 >= 0 else idx_first
    after_idx = idx_last + 1 if idx_last + 1 < len(trip_df_sorted) else idx_last

    before = trip_df_sorted.iloc[before_idx]
    after = trip_df_sorted.iloc[after_idx]
    return before, after

# -------------------------
# Core segmentation
# -------------------------
def segmented_times_between_stops_for_trip(trip_df_sorted, stop_seq, stops_df, radius=50):
    """
    Return list of dicts: each dict = {trip_id, from_stop, to_stop, tA, tB, travel_time_min}
    trip_df_sorted must be sorted by vehicle_timestamp
    """
    results = []
    trip_id = trip_df_sorted['trip_id'].iloc[0]
    for i in range(len(stop_seq)-1):
        stopA = int(stop_seq[i]); stopB = int(stop_seq[i+1])
        # lookup stops coords
        stopA_row = stops_df.loc[stops_df['stop_id']==stopA]
        stopB_row = stops_df.loc[stops_df['stop_id']==stopB]
        if stopA_row.empty or stopB_row.empty:
            continue
        stopA_lat = float(stopA_row['stop_lat'].iloc[0]); stopA_lon = float(stopA_row['stop_lon'].iloc[0])
        stopB_lat = float(stopB_row['stop_lat'].iloc[0]); stopB_lon = float(stopB_row['stop_lon'].iloc[0])

        beforeA, afterA = find_entry_exit_pings_trip_sorted(trip_df_sorted, stopA_lat, stopA_lon, radius)
        beforeB, afterB = find_entry_exit_pings_trip_sorted(trip_df_sorted, stopB_lat, stopB_lon, radius)

        # note: afterA = first ping after leaving A; beforeB = last ping before entering B (we used same logic)
        if afterA is not None and beforeB is not None:
            tA = pd.to_datetime(afterA['vehicle_timestamp'])
            tB = pd.to_datetime(beforeB['vehicle_timestamp'])
            travel_time_min = (tB - tA).total_seconds() / 60.0
            if travel_time_min > 0:
                results.append({
                    "trip_id": trip_id,
                    "from_stop": stopA,
                    "to_stop": stopB,
                    "tA": tA,
                    "tB": tB,
                    "travel_time_min": travel_time_min
                })
    return results

# -------------------------
# Final pipeline (robust)
# -------------------------
def build_clean_segments(live_df, stops_df, route_to_stop_seq,
                         radius=50, max_travel_time_min=500, max_speed_m_s=30,
                         show_progress=True):
    """
    live_df: raw pings (sample you provided)
    stops_df: stops.csv (must contain stop_id, stop_lat, stop_lon)
    route_to_stop_seq: route_to_stop_sequence.csv (columns route_id, stop_id_list)
    returns: clean_segments_df (clean stop-to-stop segments)
    """
    # normalize inputs
    live = normalize_live_df(live_df)
    stops = normalize_stops_df(stops_df)
    rts = route_to_stop_seq.copy()
    if 'route_id' not in rts.columns or 'stop_id_list' not in rts.columns:
        raise ValueError("route_to_stop_seq must contain 'route_id' and 'stop_id_list'")

    # ensure route_id types align
    try:
        rts['route_id'] = rts['route_id'].astype(int)
        live['route_id'] = live['route_id'].astype(int)
    except Exception:
        pass

    routes_present = rts[rts['route_id'].isin(live['route_id'].unique())].reset_index(drop=True)
    if routes_present.empty:
        raise ValueError("No routes in route_to_stop_seq match live_df.route_id")

    all_segments = []
    route_iter = tqdm(routes_present.itertuples(index=False), total=len(routes_present), desc="Routes") if show_progress else routes_present.itertuples(index=False)

    for row in route_iter:
        route_id = int(row.route_id)
        stop_seq = parse_stop_seq_field(row.stop_id_list)
        if len(stop_seq) < 2:
            continue

        route_pings = live[live['route_id']==route_id].copy()
        if route_pings.empty:
            continue

        # vectorized nearest-stop assignment (fast)
        # get stops coords in same order as stop_seq
        stop_coords = stops.set_index('stop_id').loc[stop_seq].reset_index()
        st_lats = stop_coords['stop_lat'].values
        st_lons = stop_coords['stop_lon'].values

        p_lats = route_pings['latitude'].values
        p_lons = route_pings['longitude'].values

        # compute (m,n) distances and pick nearest
        dmat = haversine_vectorized(p_lats, p_lons, st_lats, st_lons)  # shape (m,n)
        min_idx = np.argmin(dmat, axis=1)
        min_dists = dmat[np.arange(dmat.shape[0]), min_idx]
        closest_stop_ids = stop_coords['stop_id'].values[min_idx]

        route_pings = route_pings.reset_index(drop=True)
        route_pings['closest_stop'] = closest_stop_ids
        route_pings['dist_to_closest_stop_m'] = min_dists
        route_pings['near_stop'] = route_pings['dist_to_closest_stop_m'] <= radius

        # Only process trips that have at least one near_stop ping (optional speedup)
        trips_to_process = route_pings[route_pings['near_stop']].trip_id.unique()
        if len(trips_to_process) == 0:
            continue

        # process each trip
        for trip_id, trip_df in route_pings[route_pings['trip_id'].isin(trips_to_process)].groupby('trip_id'):
            trip_df_sorted = trip_df.sort_values('vehicle_timestamp').reset_index(drop=True)
            segs = segmented_times_between_stops_for_trip(trip_df_sorted, stop_seq, stops, radius=radius)
            if segs:
                for s in segs:
                    s['route_id'] = route_id
                    all_segments.append(s)

    if not all_segments:
        return pd.DataFrame()

    seg_df = pd.DataFrame(all_segments)

    # -------------------------
    # Enrich: distances & speeds
    # -------------------------
    # Add from/to stop coords
    seg_df = seg_df.merge(stops[['stop_id','stop_lat','stop_lon']].rename(columns={'stop_id':'from_stop','stop_lat':'from_lat','stop_lon':'from_lon'}),
                          on='from_stop', how='left')
    seg_df = seg_df.merge(stops[['stop_id','stop_lat','stop_lon']].rename(columns={'stop_id':'to_stop','stop_lat':'to_lat','stop_lon':'to_lon'}),
                          on='to_stop', how='left')

    # compute straight-line distance between stops
    seg_df['distance_m'] = seg_df.apply(lambda r: haversine_point(r['from_lat'], r['from_lon'], r['to_lat'], r['to_lon']), axis=1)
    seg_df['avg_speed_m_s'] = seg_df['distance_m'] / (seg_df['travel_time_min'] * 60.0)

    # -------------------------
    # Clean filters
    # -------------------------
    seg_df = seg_df[seg_df['travel_time_min'].between(0.001, max_travel_time_min)]
    seg_df = seg_df[seg_df['avg_speed_m_s'].between(0.0001, max_speed_m_s)]

    # temporal features
    seg_df['start_hour'] = seg_df['tA'].dt.hour
    seg_df['day_of_week'] = seg_df['tA'].dt.dayofweek

    # final ordering
    cols = ['trip_id','route_id','from_stop','to_stop','tA','tB','travel_time_min','distance_m','avg_speed_m_s','start_hour','day_of_week']
    existing_cols = [c for c in cols if c in seg_df.columns]
    clean_segments_df = seg_df[existing_cols].reset_index(drop=True)
    return clean_segments_df

clean_segments_df = build_clean_segments(combined_df, df_stops, route_to_stop_sequence,
                                         radius=35, max_travel_time_min=180, max_speed_m_s=30,
                                         show_progress=True)
# Out:
# Routes: 100%|██████████| 4083/4083 [11:36<00:00,  5.86it/s]

# %% [markdown]
# This is again just a demo of the original workflow ....... ( The original took alot of time)
